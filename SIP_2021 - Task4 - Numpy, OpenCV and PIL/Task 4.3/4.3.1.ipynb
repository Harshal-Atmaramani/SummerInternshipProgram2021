# %%
# Creating images using PIL and Numpy

# Creating 1 of 4 images to join.
import numpy as np
from PIL import Image as im
from google.colab.patches import cv2_imshow

arr = np.zeros([256,256,3], dtype=np.uint8)

for i in range(255,-1,-1):
  for j in range(255,-1,-1):
    # arr[r,c] = [B,G,R]
    arr[i,j] = [i, j, i+j]

img = im.fromarray(arr)
img.save('1.png')

# Trying to see the same image in Colab
image = cv2.imread('1.png')
cv2_imshow(image)


# Creating 2 of 4 images to join.
import numpy as np
from PIL import Image as im
from google.colab.patches import cv2_imshow

arr = np.zeros([256,256,3], dtype=np.uint8)

for i in range(255,-1,-1):
  for j in range(255,-1,-1):
    # arr[r,c] = [B,G,R]
    arr[i,j] = [k,j,i-j]

img = im.fromarray(arr)
img.save('2.png')

# Trying to see the same image in Colab
image = cv2.imread('2.png')
cv2_imshow(image)


# Creating 3 of 4 images to join.
import numpy as np
from PIL import Image as im
from google.colab.patches import cv2_imshow

arr = np.zeros([256,256,3], dtype=np.uint8)

for i in range(255,-1,-1):
  for j in range(255,-1,-1):
    # arr[r,c] = [B,G,R]
    arr[i,j] = [i,k,i-j]

img = im.fromarray(arr)
img.save('3.png')

# Trying to see the same image in Colab
image = cv2.imread('3.png')
cv2_imshow(image)


# Creating 4 of 4 images to join.
import numpy as np
from PIL import Image as im
from google.colab.patches import cv2_imshow

arr = np.zeros([256,256,3], dtype=np.uint8)

for i in range(255,-1,-1):
  for j in range(255,-1,-1):
    # arr[r,c] = [B,G,R]
    arr[i,j] = [i,i+j,k]

img = im.fromarray(arr)
img.save('4.png')

# Trying to see the same image in Colab
image = cv2.imread('4.png')
cv2_imshow(image)
